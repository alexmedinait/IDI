# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
norm = np.random.normal(size=1000)
norm
plt.hist(norm)
# Out:
# (array([  9.,  28.,  74., 164., 231., 216., 160.,  79.,  30.,   9.]),
#  array([-3.10071295, -2.48793031, -1.87514768, -1.26236504, -0.6495824 ,
#         -0.03679976,  0.57598288,  1.18876552,  1.80154816,  2.41433079,
#          3.02711343]),
#  <a list of 10 Patch objects>)

# %%
unif = np.random.uniform(size=1000)
unif
plt.hist(unif)
# Out:
# (array([ 85., 103., 117.,  97., 112.,  96., 107.,  84., 110.,  89.]),
#  array([0.00364258, 0.1031668 , 0.20269101, 0.30221522, 0.40173943,
#         0.50126364, 0.60078786, 0.70031207, 0.79983628, 0.89936049,
#         0.9988847 ]),
#  <a list of 10 Patch objects>)
